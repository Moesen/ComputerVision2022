# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import utils as u
from importlib import reload

# %% [markdown]
# ### **Exercise 7.1**

# %%
reload(u)
points = u.test_points(1, 1, return_hom=True)
a, b = points.T
line = u.estimate_line(a, b)
points.shape
# Out:
# (3, 2)

# %% [markdown]
# ### **Exercise 7.2**

# %%
reload(u)
u.in_or_out(points[:, 0], points[:, 1])
# Out:
# 3.675762167904254
# False

# %% [markdown]
# ### **Exercise 7.3**

# %%
reload(u)
points = u.test_points(50, 20, return_hom=True)
line = u.estimate_line(points[:, 0], points[:, 1])
np.set_printoptions(suppress=True)
u.calc_consenus(points, line, threshold=0.1)
# Out:
# 0

# %% [markdown]
# ### **Exercise 7.4**

# %%
reload(u)
u.draw_random(points)
# Out:
# array([[ 3.76344996, -3.7045412 ],
#        [ 1.71224751, -1.67916154],
#        [ 1.        ,  1.        ]])

# %% [markdown]
# ### **Exercise 7.5**

# %%
reload(u)
line = u.RANSAC(points)
# Out:
# /home/snooze/Git/ComputerVision2022/exercises/utils.py:300: RuntimeWarning: divide by zero encountered in double_scalars
#   _n = np.log(1 - p) / np.log(1 - (1 - _eps) ** num_datapoints)

# %% [markdown]
# ### **Exercise 7.6**

# %%
reload(u)
points = u.test_points(50, 20, return_hom=True)
threshold = 0.5
line, ps = u.RANSAC(points, threshold=threshold, return_points=True)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
u.plot_homo_line(line, points, threshold=threshold, ax=ax)
ax.scatter(*ps.T[:2], 5, c="red")

np.max(line @ points)
# Out:
# /home/snooze/Git/ComputerVision2022/exercises/utils.py:300: RuntimeWarning: divide by zero encountered in double_scalars
#   _n = np.log(1 - p) / np.log(1 - (1 - _eps) ** num_datapoints)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3561147/669505360.py in <module>
#       5
#       6 fig, ax = plt.subplots(1, 1, figsize=(10, 10))
# ----> 7 u.plot_homo_line(line, points, threshold=threshold, ax=ax)
#       8 ax.scatter(*ps.T[:2], 5, c="red")
#       9
#
# ~/Git/ComputerVision2022/exercises/utils.py in plot_homo_line(line, points, threshold, ax)
#     334     line: np.array, points: np.array, threshold: int, ax: plt.Axes = None
#     335 ):
# --> 336     assert len(line.shape) == 1
#     337     a = line[0] / line[1]
#     338     b = line[2] / line[1]
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ### **Exercise 7.7** - PCA Line

# %%
reload(u)
inhom_ps = u.hom_to_inhom(ps.T)
pca_line = u.pca_line(inhom_ps)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7.5))
u.plot_homo_line(line, points, threshold, ax=ax1)
u.plot_homo_line(pca_line, points, threshold, ax=ax2)

# %% [markdown]
# ### **Exercise 7.8**

# %%
reload(u)
points = u.test_points(100, 50, return_hom=True)
threshold = 0.5
line, ps = u.RANSAC(points, threshold, return_points=True)
inhom_ps = u.hom_to_inhom(ps.T)
pca_line = u.pca_line(inhom_ps)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7.5))
u.plot_homo_line(line, points, threshold, ax=ax1)
u.plot_homo_line(pca_line, points, threshold, ax=ax2)
# Out:
# /home/snooze/Git/ComputerVision2022/exercises/utils.py:300: RuntimeWarning: divide by zero encountered in double_scalars
#   _n = np.log(1 - p) / np.log(1 - (1 - _eps) ** num_datapoints)
# /home/snooze/Git/ComputerVision2022/exercises/utils.py:326: RuntimeWarning: Degrees of freedom <= 0 for slice
#   d = np.cov(x)[:, 0]
# /home/snooze/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/snooze/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:2493: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
